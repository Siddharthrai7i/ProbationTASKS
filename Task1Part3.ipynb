# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib as plt

# %%
sdata=pd.read_csv('diabetes.csv')

# %%
sdata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
newdata=sdata.Outcome>0

# %%
newdataF=sdata[newdata]

# %%
newdataF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
meddata=newdataF.Age<50

# %%
meddataF=newdataF[meddata]
meddataF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
middledata=meddataF.Age>30
middledataF=meddataF[middledata]
middledataF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
middledata.sum()
# Out:
# 178

# %% [markdown]
# there are 178 people who are diabetes +ve and and there age is between 30 to 50 year

# %%
agedata=sdata.Age>30

# %%
agedataF=sdata[agedata]

# %%
agedataF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
midage=agedataF.Age<50
midage.sum()
# Out:
# 262

# %% [markdown]
# **here are total 262 peoples whose age is between 30 year to 50 year**

# %% [markdown]
# **NOW WE WILL calculate the percentage in this age**

# %%
percent=((middledata.sum())/midage.sum())*100

# %%
percent
# Out:
# 67.93893129770993

# %% [markdown]
# **The per centage of Being Diabetes positive in people age between 30 to 50 year is ****68%**

# %% [markdown]
# **The CONCLUSION**

# %% [markdown]
# 1.**the diabeties +ve percentage in old persons (age>50)** is **47%**

# %% [markdown]
# 2.**the diabeties +ve percentage in middle age persons (30< age <50)** is **68%**

# %% [markdown]
# 3.**the diabeties +ve percentage in Adults and Teenegers persons (age<30)** is **21%**

# %% [markdown]
# ***FINAL***

# %% [markdown]
# **IF your age is between 30 to 50 years be careful of being DIABETES +ve**
