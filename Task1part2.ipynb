# %% [markdown]
# ***MATHEMATICAL CALCULATION**

# %% [markdown]
# *1*  how many peoples are diabetes +ve
#
# *2*  how many people are 50+ year old in given data
#
# *3*  **how many people are 50+ year old  as well as covid +ve**
#
# *4*  what is the percentage of being diabetes when age above 50+
#
# *5*  how many people are less than 30 year old in given data set
#
# *6*  how many people are less than 30 year old and are diabaties positive
#
# *7*  what is the percentage of being diabetes when age less 30...........

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib as plt

# %%
sdata=pd.read_csv('diabetes.csv')

# %%
sdata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diaposi=sdata.Outcome>0

# %%
diaposi
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763    False
# 764    False
# 765    False
# 766     True
# 767    False
# Name: Outcome, Length: 768, dtype: bool

# %%
diaposi.sum()
# Out:
# 268

# %% [markdown]
# **HERE** ****268*** **are diabetes +ve**

# %%
gage=sdata.Age>50
gage.sum()
# Out:
# 81

# %% [markdown]
# ***81*** people are more than 50 year old in total data

# %%
diaposidata=sdata[diaposi]
diaposidata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# **this is data of the people who are Diabetes +ve**

# %%
oldpdata=diaposidata.Age>50
oldpdataF=diaposidata[oldpdata]

# %% [markdown]
# **The data of the people who are more than 50 year old and diabetes patient**

# %%
oldpdataF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 24            11      143             94             33      146  36.6
# 39             4      111             72             47      207  37.1
# 43             9      171            110             24      240  45.4
# 53             8      176             90             34      300  33.7
# 93             4      134             72              0        0  23.8
# 115            4      146             92              0        0  31.2
# 129            0      105             84              0        0  27.9
# 186            8      181             68             36      495  30.1
# ...

# %%
oldpdataF.shape
# Out:
# (38, 9)

# %%
oldpdata.sum()
# Out:
# 38

# %% [markdown]
# **There  are 38 people who are more than 50 year old and diabetes patient**

# %% [markdown]
# **thare are 81 people over 50 year age**
#
# **NOW THE PERCENTAGE OF THE PEOPLE OF BEING DIABETES +VE OVER 50 YEAR**

# %%
percentage=(oldpdata.sum()/gage.sum())*100

# %%
percentage
# Out:
# 46.913580246913575

# %% [markdown]
# **THE PERCENTAGE OF BEING DIABETES POSITIVE OVER 50 YEAR IS** ***47%** (according to this data )

# %% [markdown]
# now finding average blood pressure of these peoples

# %%
oldpdata.sum()
# Out:
# 38

# %%
average_BP=oldpdataF.BloodPressure.sum()/gage.sum()

# %%
average_BP
# Out:
# 38.20987654320987

# %%
sdata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
teendata=sdata.Age<30
teendata.sum()
# Out:
# 396

# %% [markdown]
# ***696 people are less than 30 year old**

# %%
teegerdata=sdata[teendata]
teegerdata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 20             3      126             88             41      235  39.3
# 23             9      119             80             35        0  29.0
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
dibpteeni=teegerdata.Outcome>0
#dia +ve teenegers 
dibpteeni.sum()
# Out:
# 84

# %%
**84 of total 396 teengers are diabetes patient***

# %%
dibpteeniF=teegerdata[teegerdata.Outcome>0]
dibpteeniF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6              3       78             50             32       88  31.0
# 23             9      119             80             35        0  29.0
# 31             3      158             76             36      245  31.6
# 38             2       90             68             42        0  38.2
# 45             0      180             66             39        0  42.0
# ..           ...      ...            ...            ...      ...   ...
# 731            8      120             86              0        0  28.4
# 732            2      174             88             37      120  44.5
# 746            1      147             94             41        0  49.3
# 750            4      136             70              0        0  31.2
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 6                       0.248   26        1
# ...

# %%
perct1=(dibpteeni.sum()/teendata.sum())*100
perct1
# Out:
# 21.21212121212121

# %% [markdown]
# **percentage of beeing biabetes is 21.21 in teen.**
