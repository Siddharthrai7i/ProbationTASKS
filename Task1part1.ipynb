# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
dbdata=pd.read_csv('diabetes.csv')

# %%
dbdata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dbdata.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dbdata.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
dbdata.shape
# Out:
# (768, 9)

# %%
dbdata.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dbdata.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
dbdata.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
dbdata.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# .isnull() me agar koi INTEGER value rahegi to False deta hai

# %%
dbdata.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %% [markdown]
# koi ek line me sare data same rhenge to True dega ;;;

# %%
dbdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dbdata.drop(['SkinThickness'], axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ...

# %% [markdown]
# agar kisis ek data ka ka nhi hai to use delete krte hai

# %%
dbdata
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dbdata=dbdata.drop(['SkinThickness'], axis=1)

# %%
dbdata
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ...

# %%
corelation=dbdata.corr()

# %%
corelation
# Out:
#                           Pregnancies   Glucose  BloodPressure   Insulin  \
# Pregnancies                  1.000000  0.129459       0.141282 -0.073535
# Glucose                      0.129459  1.000000       0.152590  0.331357
# BloodPressure                0.141282  0.152590       1.000000  0.088933
# Insulin                     -0.073535  0.331357       0.088933  1.000000
# BMI                          0.017683  0.221071       0.281805  0.197859
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265  0.185071
# Age                          0.544341  0.263514       0.239528 -0.042163
# Outcome                      0.221898  0.466581       0.065068  0.130548
#
#                                BMI  DiabetesPedigreeFunction       Age  \
# Pregnancies               0.017683                 -0.033523  0.544341
# Glucose                   0.221071                  0.137337  0.263514
# BloodPressure             0.281805                  0.041265  0.239528
# ...

# %% [markdown]
# ye data k khud k aur pure neumeric value ko compare krta hai aur relational value deta hai
# **DOUBT** ***ye negative aur positive kyu deta hai aur kaise find krta hai ye valuse***

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.rows, annot=True)
# **DOUBT** **kyunhi chalta ye** *******kya agar row me koi data hota to ye kam krta !!!****** **matlab heading type jaise column me hai**

# %%
sns.pairplot(dbdata)

# %%
sns.relplot(x='Pregnancies' , y='Glucose' , hue='Age' , kind='line' , data=dbdata)

# %%
newdata=dbdata.head(100)
newdata
# Out:
#     Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0             6      148             72        0  33.6
# 1             1       85             66        0  26.6
# 2             8      183             64        0  23.3
# 3             1       89             66       94  28.1
# 4             0      137             40      168  43.1
# ..          ...      ...            ...      ...   ...
# 95            6      144             72      228  33.9
# 96            2       92             62        0  31.6
# 97            1       71             48       76  20.4
# 98            6       93             50       64  28.7
# 99            1      122             90      220  49.7
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# ...

# %%
sns.relplot(x='Pregnancies' , y='Glucose' , hue='Age' , kind='line' , data=newdata)

# %% [markdown]
# **Doubt**
# How it is foemed and in this case data is not showing

# %%
sns.relplot(x='Pregnancies' , y='Glucose'  , kind='line' , data=newdata)

# %%
sns.relplot(x='Pregnancies' , y='Glucose'  , hue='BMI' ,  kind='line' , data=newdata)

# %% [markdown]
# **DOUBT** **sie hue kya hai **

# %%
sns.histplot(dbdata['Pregnancies'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Count'>

# %%
sns.lineplot(dbdata['Pregnancies'])
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
sns.scatterplot(dbdata['Pregnancies'])
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
sns.relplot(newdata['Pregnancies'])

# %%
sns.lineplot(newdata['Pregnancies'])
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
sns.histplot(dbdata['Pregnancies'])
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Count'>
